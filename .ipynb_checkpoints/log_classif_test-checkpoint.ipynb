# %% [markdown]
# # Technique d'apprentissage

# %% [markdown]
# ### Visualisation des données

# %%
import numpy as np
from models.logistic_reg import Logistic
from models.adaboost import Adaboost
from models.mlp import Mlp
from models.svm import Svm
from models.decision_tree import Forest
from models.mixedsamples import MixedSamples
import pandas as pd
from utils import plot_learning_curve
import warnings
from get_data.get_dataset import training_set, test_set
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ### Visualisation du jeu de données

# %%
training_set = training_set.sample(frac=1).reset_index(drop=True)
training_set.head(10)
# Out:
#    contrast_0  contrast_45  contrast_90  contrast_135  correlation_0  \
# 0   -1.156240    -1.214012    -1.004520     -1.128115       0.474029
# 1    0.682847    -0.076738    -0.628663     -0.032394      -1.286985
# 2   -0.130759    -0.355104    -0.584264     -0.365753       1.188136
# 3   -0.970530    -1.027958    -0.901686     -1.000567       0.982310
# 4   -1.389472    -1.406847    -0.712975     -0.943197       0.850611
# 5   -1.239694    -1.336502    -1.296457     -1.349787       0.670763
# 6    0.970161     1.171934     1.100263      1.014902      -0.048935
# 7   -0.806656    -0.965922    -0.772221     -0.820808       1.027446
# 8    0.976382     0.974418     0.691618      0.805029       0.201004
# 9    1.274166     0.990536     0.571592      0.967470       0.143681
#
#    correlation_45  correlation_90  correlation_135  energy_0  energy_45  ...  \
# 0        0.703906        0.681659         0.596506 -0.735770  -0.745420  ...
# 1       -0.464261        0.362170        -0.520635 -0.683084  -0.653002  ...
# 2        1.333418        1.274279         1.340937  1.382518   1.384335  ...
# 3        1.135306        1.020844         1.110741  2.343364   2.326725  ...
# 4        1.068148        0.314880         0.444675 -0.629193  -0.652029  ...
# 5        0.969331        1.181237         0.992268 -0.734607  -0.733919  ...
# 6       -0.359684       -0.546135        -0.229200  0.157938   0.183067  ...
# 7        1.250236        1.003335         1.109257 -0.387271  -0.375464  ...
# 8        0.071174        0.028519         0.201617  0.902552   0.913542  ...
# 9        0.210977        0.250154         0.222764  2.400260   2.394293  ...
#
#    std3HF_D  std2HF_H  std2HF_V  mean2HF_D  std2HF_D  std1HF_H  std1HF_V  \
# 0 -0.819148 -0.424049 -1.230897  -0.412690 -1.260771  0.039555 -0.541364
# 1 -0.576368 -1.474730 -0.412053   0.476363  0.100005 -0.938334  0.397321
# 2  0.358940 -0.835947  0.385997   0.817477 -0.160383 -1.104949 -0.467052
# 3 -0.880962 -0.952387 -0.761600   0.890055 -1.060184 -1.078564 -0.433854
# 4 -1.059328 -0.783174 -1.286015   1.390778 -0.320332 -1.019872 -1.026313
# 5 -0.534738 -0.850176 -0.878086  -0.728112 -1.387141 -0.395261 -0.548834
# 6  1.067226  0.912914  0.754173  -0.593320  0.596993  0.870887  0.290311
# 7 -0.882761 -1.109258 -0.637240  -0.386354 -0.685952 -1.225578 -0.736795
# 8  1.133748  1.127135  1.172698  -0.579740  1.101537  1.189267  0.504790
# 9  0.417383  0.595413  1.548978   0.513632  0.955606  0.660026  0.742298
#
#    mean1HF_D  std1HF_D  class
# 0  -1.110370 -0.840087    1.0
# 1  -2.236960  0.438871    1.0
# 2   1.715797 -0.410374    1.0
# 3  -0.837191 -0.878732    1.0
# 4  -0.033063 -0.970024    1.0
# 5   0.047566 -1.217139    1.0
# 6  -1.050248  0.865031    0.0
# 7   1.469307 -0.334109    1.0
# 8   3.201701  0.718898    0.0
# 9  -1.989536  1.119903    1.0
#
# [10 rows x 31 columns]

# %%
x_train = training_set.loc[:, training_set.columns != 'class'].to_numpy()
y_train = np.squeeze(training_set.loc[:, training_set.columns == 'class'].to_numpy())
x_test = test_set.loc[:, test_set.columns != 'class'].to_numpy()
y_test = np.squeeze(test_set.loc[:, test_set.columns == 'class'].to_numpy())

# %% [markdown]
# # Logistic classifier

# %%
log = Logistic(hyperparams=[0.01, 0.001])

# %% [markdown]
# #### Cross-Validation:

# %%
log.train(x_train, y_train, tuning=True)
print(log)
# Out:
# Tuple testé: [0.0001, 0.1]
# Error moyenne:  6.577567965495388
# Tuple meilleur! On change pour:[0.0001, 0.1] et une erreur moyenne de 6.577567965495388
# Tuple testé: [0.001, 0.1]
# Error moyenne:  4.622807993265785
# Tuple meilleur! On change pour:[0.001, 0.1] et une erreur moyenne de 4.622807993265785
# Tuple testé: [0.01, 0.1]
# Error moyenne:  4.385097087958625
# Tuple meilleur! On change pour:[0.01, 0.1] et une erreur moyenne de 4.385097087958625
# Tuple testé: [0.1, 0.1]
# Error moyenne:  4.424718477023745
# Tuple testé: [0.0001, 0.2]
# Error moyenne:  7.211547189118217
# Tuple testé: [0.001, 0.2]
# Error moyenne:  4.847342753922018
# Tuple testé: [0.01, 0.2]
# Error moyenne:  4.807758669211194
# Tuple testé: [0.1, 0.2]
# Error moyenne:  5.085139581553418
# Tuple testé: [0.0001, 0.5]
# Error moyenne:  6.5907768278996715
# Tuple testé: [0.001, 0.5]
# Error moyenne:  4.688856891888141
# Tuple testé: [0.01, 0.5]
# Error moyenne:  5.798386656724951
# Tuple testé: [0.1, 0.5]
# Error moyenne:  5.996515617735056
# Tuple testé: [0.0001, 1]
# Error moyenne:  6.696438248158667
# Tuple testé: [0.001, 1]
# Error moyenne:  5.349277996417811
# Tuple testé: [0.01, 1]
# Error moyenne:  6.881474540654919
# Tuple testé: [0.1, 1]
# Error moyenne:  7.06638730069924
# Tuple testé: [0.0001, 2]
# Error moyenne:  6.683229079980987
# Tuple testé: [0.001, 2]
# Error moyenne:  6.049330886308061
# Tuple testé: [0.01, 2]
# Error moyenne:  7.766440496362887
# Tuple testé: [0.1, 2]
# Error moyenne:  8.14947824236317
# Les hyperamètres sont:
# lr:0.01
# alpha:0.1

# %% [markdown]
# #### Test plotting learning curves:
# Plot les courbes d'apprentissages et utilise une cross-validation pour vérifier les paramètres du modèle. La fonction prend en entrée l'objet sans entraînement et init plusieurs fois l'objet avec les bons paramètres.

# %%
log.reinit()
plot_learning_curve(log.logistic_classifier, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# #### Matrice de confusion avec les meilleurs paramètres:

# %%
log.train(x_train, y_train, tuning=False)
justesse_log, confusion_matrix = log.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7099358974358975%
#    Prédit normal  Prédit malade
# 0       0.131410       0.243590
# 1       0.046474       0.578526

# %% [markdown]
# ### Courbes ROC et précision-rappel:
# Pour rappel:
# - La ROC correspond aux taux de vrais positifs (pneumonia bien détectée) en fonction du taux de faux positifs (taux de normal détecté comme pneuomia)
# - La précision-rappel correspond à la précision (nombre de pneumonies détectées par rapport aux nombre de pneumonia réelles détectées + nombres de pneumonie fausses détectées (en gros le nombre de pneumonie bien detectées par rapport à tout ce qu'il a detecté)) en fonction du rappel (ou sensibilité: nombre de pneumonie détectées sur le nombres de pneumonies réelles détectées + les pneumonies réelles non détectées)

# %%
roc, pres_rec = log.get_curves(x_test, y_test)

# %% [markdown]
# # Adaboost:

# %%
ada = Adaboost([0.1])

# %%
# Cross-validation !!!!
ada.train(x_train, y_train, tuning=True)
print(ada)
# Out:
# Tuple testé: [1]
# Error moyenne:  0.10936902485659657
# Tuple meilleur! On change pour:[1] et une erreur moyenne de 0.10936902485659657
# Tuple testé: [0.1]
# Error moyenne:  0.12351816443594646
# Tuple testé: [0.001]
# Error moyenne:  0.16443594646271512
# Tuple testé: [0.0001]
# Error moyenne:  0.16940726577437862
# Estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=1, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
# Les hyperamètres sont:
# lr:1

# %%
ada.train(x_train, y_train, tuning=False)
justesse_ada, confusion_matrix = ada.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.719551282051282%
#    Prédit normal  Prédit malade
# 0       0.149038       0.225962
# 1       0.054487       0.570513

# %%
roc, pres_rec = ada.get_curves(x_test, y_test)

# %%
ada.reinit()
plot_learning_curve(ada.adaboost_classifier, "Adaboost",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # Multi-Layer Perceptron

# %%
mlp = Mlp([10, 0.1, 0.1])

# %%
# Cross-validation !!!!
mlp.train(x_train, y_train, tuning=True)
print(mlp)
# Out:
# Tuple testé: [2, 0.9, 0.001]
# Error moyenne:  16.90627290616381
# Tuple meilleur! On change pour:[2, 0.9, 0.001] et une erreur moyenne de 16.90627290616381
# Tuple testé: [10, 0.9, 0.001]
# Error moyenne:  7.1324050104352175
# Tuple meilleur! On change pour:[10, 0.9, 0.001] et une erreur moyenne de 7.1324050104352175
# Tuple testé: [30, 0.9, 0.001]
# Error moyenne:  7.429536379951014
# Tuple testé: [60, 0.9, 0.001]
# Error moyenne:  6.637039799634531
# Tuple meilleur! On change pour:[60, 0.9, 0.001] et une erreur moyenne de 6.637039799634531
# Tuple testé: [100, 0.9, 0.001]
# Error moyenne:  5.283220841913767
# Tuple meilleur! On change pour:[100, 0.9, 0.001] et une erreur moyenne de 5.283220841913767
# Tuple testé: [2, 0.7, 0.001]
# Error moyenne:  16.443962722013886
# Tuple testé: [10, 0.7, 0.001]
# Error moyenne:  6.7691444767806495
# Tuple testé: [30, 0.7, 0.001]
# Error moyenne:  9.113506569897815
# Tuple testé: [60, 0.7, 0.001]
# Error moyenne:  5.613420997883143
# Tuple testé: [100, 0.7, 0.001]
# Error moyenne:  5.811524121041298
# Tuple testé: [2, 0.5, 0.001]
# Error moyenne:  24.83093752253371
# Tuple testé: [10, 0.5, 0.001]
# Error moyenne:  11.953231580515197
# Tuple testé: [30, 0.5, 0.001]
# Error moyenne:  5.976663949567449
# Tuple testé: [60, 0.5, 0.001]
# Error moyenne:  5.877577606264591
# Tuple testé: [100, 0.5, 0.001]
# Error moyenne:  4.655841921552234
# Tuple meilleur! On change pour:[100, 0.5, 0.001] et une erreur moyenne de 4.655841921552234
# Tuple testé: [2, 0.2, 0.001]
# Error moyenne:  8.750326301759662
# Tuple testé: [10, 0.2, 0.001]
# Error moyenne:  7.033285796492304
# Tuple testé: [30, 0.2, 0.001]
# Error moyenne:  6.9672781772783905
# Tuple testé: [60, 0.2, 0.001]
# Error moyenne:  6.537955749632143
# Tuple testé: [100, 0.2, 0.001]
# Error moyenne:  5.184154373881642
# Tuple testé: [2, 0.9, 0.1]
# Error moyenne:  19.151574646716767
# Tuple testé: [10, 0.9, 0.1]
# Error moyenne:  15.189219405527126
# Tuple testé: [30, 0.9, 0.1]
# Error moyenne:  8.882374410827545
# Tuple testé: [60, 0.9, 0.1]
# Error moyenne:  6.504977166330345
# Tuple testé: [100, 0.9, 0.1]
# Error moyenne:  4.127512651686056
# Tuple meilleur! On change pour:[100, 0.9, 0.1] et une erreur moyenne de 4.127512651686056
# Tuple testé: [2, 0.7, 0.1]
# Error moyenne:  9.906084944597692
# Tuple testé: [10, 0.7, 0.1]
# Error moyenne:  12.976818276060019
# Tuple testé: [30, 0.7, 0.1]
# Error moyenne:  6.868161256635946
# Tuple testé: [60, 0.7, 0.1]
# Error moyenne:  5.448327799799863
# Tuple testé: [100, 0.7, 0.1]
# Error moyenne:  5.052077216341152
# Tuple testé: [2, 0.5, 0.1]
# Error moyenne:  14.760022344973185
# Tuple testé: [10, 0.5, 0.1]
# Error moyenne:  12.217502853920099
# Tuple testé: [30, 0.5, 0.1]
# Error moyenne:  6.537986326971729
# Tuple testé: [60, 0.5, 0.1]
# Error moyenne:  5.250191806001652
# Tuple testé: [100, 0.5, 0.1]
# Error moyenne:  5.283215490879339
# Tuple testé: [2, 0.2, 0.1]
# Error moyenne:  17.43456854095644
# Tuple testé: [10, 0.2, 0.1]
# Error moyenne:  13.439158273116039
# Tuple testé: [30, 0.2, 0.1]
# Error moyenne:  7.2314462521621845
# Tuple testé: [60, 0.2, 0.1]
# Error moyenne:  6.339831986769767
# Tuple testé: [100, 0.2, 0.1]
# Error moyenne:  5.943613509517622
# Tuple testé: [2, 0.9, 0.5]
# Error moyenne:  21.09975877755674
# Tuple testé: [10, 0.9, 0.5]
# Error moyenne:  7.957869471984642
# Tuple testé: [30, 0.9, 0.5]
# Error moyenne:  5.481343840342653
# Tuple testé: [60, 0.9, 0.5]
# Error moyenne:  6.042687621884646
# Tuple testé: [100, 0.9, 0.5]
# Error moyenne:  5.31623306028911
# Tuple testé: [2, 0.7, 0.5]
# Error moyenne:  8.486241550126245
# Tuple testé: [10, 0.7, 0.5]
# Error moyenne:  14.462710569153826
# Tuple testé: [30, 0.7, 0.5]
# Error moyenne:  9.113560080242092
# Tuple testé: [60, 0.7, 0.5]
# Error moyenne:  6.504959584360083
# Tuple testé: [100, 0.7, 0.5]
# Error moyenne:  5.118110061860223
# Tuple testé: [2, 0.5, 0.5]
# Error moyenne:  14.297641832942215
# Tuple testé: [10, 0.5, 0.5]
# Error moyenne:  14.297690756685554
# Tuple testé: [30, 0.5, 0.5]
# Error moyenne:  10.104116211007819
# Tuple testé: [60, 0.5, 0.5]
# Error moyenne:  6.901196408015979
# Tuple testé: [100, 0.5, 0.5]
# Error moyenne:  5.382267434675162
# Tuple testé: [2, 0.2, 0.5]
# Error moyenne:  17.005332494294528
# Tuple testé: [10, 0.2, 0.5]
# Error moyenne:  6.835246121313792
# Tuple testé: [30, 0.2, 0.5]
# Error moyenne:  6.372896951055896
# Tuple testé: [60, 0.2, 0.5]
# Error moyenne:  5.613407238080329
# Tuple testé: [100, 0.2, 0.5]
# Error moyenne:  4.556782333421515
# Les hyperamètres sont:
# hidden_layer_sizes:100
# alpha:0.9
# momentum:0.1

# %%
justesse_mlp, confusion_matrix = mlp.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7435897435897436%
#    Prédit normal  Prédit malade
# 0       0.213141       0.161859
# 1       0.094551       0.530449

# %%
roc, pres_rec = mlp.get_curves(x_test, y_test)

# %%
mlp.reinit()
plot_learning_curve(mlp.mlp, "multi layer perceptron",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # SVM

# %%
svmrbf = Svm('rbf', ['gamma', 'régularisation'],[100,0.0001])
svmlinear = Svm('linear', ['None'],[])
svmpolynomial = Svm('poly', ['degree'],[1])

# %%
svmrbf.train(x_train, y_train, tuning=True)
svmlinear.train(x_train, y_train, tuning=True)
svmpolynomial.train(x_train, y_train, tuning=True)
print(svmrbf)

print(svmpolynomial)
# Out:
# Tuple testé: [1, 0.001]
# Error moyenne:  0.38718929254302104
# Tuple meilleur! On change pour:[1, 0.001] et une erreur moyenne de 0.38718929254302104
# Tuple testé: [10, 0.001]
# Error moyenne:  0.3565965583173996
# Tuple meilleur! On change pour:[10, 0.001] et une erreur moyenne de 0.3565965583173996
# Tuple testé: [100, 0.001]
# Error moyenne:  0.3575525812619503
# Tuple testé: [1000, 0.001]
# Error moyenne:  0.3212237093690249
# Tuple meilleur! On change pour:[1000, 0.001] et une erreur moyenne de 0.3212237093690249
# Tuple testé: [1, 0.0001]
# Error moyenne:  0.38240917782026773
# Tuple testé: [10, 0.0001]
# Error moyenne:  0.38910133843212236
# Tuple testé: [100, 0.0001]
# Error moyenne:  0.361376673040153
# Tuple testé: [1000, 0.0001]
# Error moyenne:  0.38049713193116635
# Tuple testé: [1]
# Error moyenne:  0.3317399617590822
# Tuple meilleur! On change pour:[1] et une erreur moyenne de 0.3317399617590822
# Tuple testé: [2]
# Error moyenne:  0.4101338432122371
# Tuple testé: [3]
# Error moyenne:  0.3852772466539197
# Tuple testé: [4]
# Error moyenne:  0.4072657743785851
# Tuple testé: [5]
# Error moyenne:  0.4225621414913958
# Tuple testé: [6]
# Error moyenne:  0.4235181644359465
# Tuple testé: [7]
# Error moyenne:  0.3986615678776291
# Tuple testé: [8]
# Error moyenne:  0.43212237093690253
# Tuple testé: [9]
# Error moyenne:  0.4445506692160612
# Tuple testé: [10]
# Error moyenne:  0.44550669216061184
# Les hyperamètres sont:
# gamma:1000
# régularisation:0.001
#
# Les hyperamètres sont:
# degree:1

# %%
justesse_svmrbf, confusion_matrix = svmrbf.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())

justesse_linear, confusion_matrix = svmlinear.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())

justesse_svmpoly, confusion_matrix = svmpolynomial.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7355769230769231%
#    Prédit normal  Prédit malade
# 0       0.153846       0.221154
# 1       0.043269       0.581731
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7147435897435898%
#    Prédit normal  Prédit malade
# 0       0.141026       0.233974
# 1       0.051282       0.573718
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7147435897435898%
#    Prédit normal  Prédit malade
# 0       0.144231       0.230769
# 1       0.054487       0.570513

# %%
oc, pres_rec = svmrbf.get_curves(x_test, y_test)
oc, pres_rec = svmlinear.get_curves(x_test, y_test)
oc, pres_rec = svmpolynomial.get_curves(x_test, y_test)

# %%
svmrbf.reinit()
plot_learning_curve(svmrbf.model, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %%
svmlinear.reinit()
plot_learning_curve(svmlinear.model, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %%
svmpolynomial.reinit()
plot_learning_curve(svmpolynomial.model, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # Decision Tree

# %%
# ['max_depth', 'min_samples_leaf,min_samples_split,n_estimators']
forest = Forest([10, 3, 5, 200])

# %%
forest.train(x_train, y_train, tuning=True)
print(forest)
# Out:
# Tuple testé: [10, 2, 2, 200]
# Error moyenne:  0.09847036328871893
# Tuple meilleur! On change pour:[10, 2, 2, 200] et une erreur moyenne de 0.09847036328871893
# Tuple testé: [20, 2, 2, 200]
# Error moyenne:  0.08891013384321224
# Tuple meilleur! On change pour:[20, 2, 2, 200] et une erreur moyenne de 0.08891013384321224
# Tuple testé: [10, 3, 2, 200]
# Error moyenne:  0.10707456978967494
# Tuple testé: [20, 3, 2, 200]
# Error moyenne:  0.0965583173996176
# Tuple testé: [10, 2, 5, 200]
# Error moyenne:  0.09369024856596558
# Tuple testé: [20, 2, 5, 200]
# Error moyenne:  0.0841300191204589
# Tuple meilleur! On change pour:[20, 2, 5, 200] et une erreur moyenne de 0.0841300191204589
# Tuple testé: [10, 3, 5, 200]
# Error moyenne:  0.0994263862332696
# Tuple testé: [20, 3, 5, 200]
# Error moyenne:  0.08508604206500955
# Tuple testé: [10, 2, 2, 400]
# Error moyenne:  0.10229445506692161
# Tuple testé: [20, 2, 2, 400]
# Error moyenne:  0.0994263862332696
# Tuple testé: [10, 3, 2, 400]
# Error moyenne:  0.10133843212237093
# Tuple testé: [20, 3, 2, 400]
# Error moyenne:  0.1089866156787763
# Tuple testé: [10, 2, 5, 400]
# Error moyenne:  0.10325047801147227
# Tuple testé: [20, 2, 5, 400]
# Error moyenne:  0.0869980879541109
# Tuple testé: [10, 3, 5, 400]
# Error moyenne:  0.0965583173996176
# Tuple testé: [20, 3, 5, 400]
# Error moyenne:  0.09273422562141492
# Les hyperamètres sont:
# max_depth:20
# min_samples_leaf:2
# min_samples_split:5
# n_estimators:200

# %%
justesse_forest, confusion_matrix = forest.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7387820512820513%
#    Prédit normal  Prédit malade
# 0       0.157051       0.217949
# 1       0.043269       0.581731

# %%
roc, pres_rec = forest.get_curves(x_test, y_test)

# %%
forest.reinit()
plot_learning_curve(forest.forest, "Forest",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # Model Mixture

# %%
 mix = MixedSamples('erer',hyperparams=[])

# %%
mix.train(x_train,y_train)
print("finish")
# Out:
# finish

# %%
justesse_mix, confusion_matrix = mix.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# (624, 7)
# Justesse: 0.719551282051282%
#    Prédit normal  Prédit malade
# 0       0.142628       0.232372
# 1       0.048077       0.576923

# %%
roc, pres_rec = mix.get_curves(x_test, y_test)

# %% [markdown]
# # Resultats

# %%
juste = pd.DataFrame([justesse_log,justesse_ada,justesse_mlp,justesse_linear,justesse_svmpoly,justesse_forest,justesse_svmrbf,justesse_mix]).T
juste.columns = ['log','ada','mlp','svm linear', 'svm poly', 'foret', 'svm rbf', 'mix']
juste.head()
# Out:
#         log       ada      mlp  svm linear  svm poly     foret   svm rbf  \
# 0  0.709936  0.719551  0.74359    0.714744  0.714744  0.738782  0.735577
#
#         mix
# 0  0.719551
