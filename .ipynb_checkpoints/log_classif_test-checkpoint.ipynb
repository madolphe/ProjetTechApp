# %% [markdown]
# # Projet Technique d'apprentissage

# %% [markdown]
# ### Visualisation du jeu de données

# %%
import numpy as np
from models.logistic_reg import Logistic
from models.adaboost import Adaboost
from models.mlp import Mlp
from get_data.get_dataset import training_set, test_set
import pandas as pd
from utils import plot_learning_curve
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
training_set = training_set.sample(frac=1).reset_index(drop=True)
training_set.head(10)
# Out:
#    contrast_0  contrast_45  contrast_90  contrast_135  correlation_0  \
# 0   -1.463427    -1.336562    -1.167404     -1.516845       0.490700
# 1   -0.224442    -0.273931    -0.518018     -0.476119       1.467242
# 2    0.944768     0.408393    -0.007228      0.445656       0.161578
# 3   -1.586321    -1.356127    -0.881641     -1.240710       0.578033
# 4    1.169887     0.545964    -0.859868     -0.117442      -3.054708
# 5   -0.484149    -0.303838    -0.550435     -0.670644       1.394927
# 6   -0.698680    -0.650035    -0.683240     -0.969374       0.325414
# 7   -0.588712    -0.841777    -0.652562     -0.557288      -0.582279
# 8    0.738825     1.172759     1.624308      1.141814       0.031568
# 9   -1.707825    -1.583073    -1.155099     -1.524989       1.667432
#
#    correlation_45  correlation_90  correlation_135  energy_0  energy_45  ...  \
# 0        0.527018        0.700413         0.833236 -0.683231  -0.700764  ...
# 1        1.488109        1.359959         1.622210  5.276810   5.215701  ...
# 2        0.477179        0.613049         0.442623  1.147870   1.145923  ...
# 3        0.471009        0.141176         0.287086 -0.597269  -0.609194  ...
# 4       -2.347953        0.212348        -1.308649 -0.741169  -0.738625  ...
# 5        1.271752        1.229412         1.547367  2.076270   2.075616  ...
# 6        0.332120        0.490803         0.733046 -0.629240  -0.609166  ...
# 7       -0.122329       -0.105416        -0.557530 -0.707594  -0.697994  ...
# 8       -0.483080       -1.157695        -0.461841  0.316107   0.309505  ...
# 9        1.720390        1.301738         1.665540 -0.579671  -0.563847  ...
#
#    std3HF_D  std2HF_H  std2HF_V  mean2HF_D  std2HF_D  std1HF_H  std1HF_V  \
# 0 -0.940220 -0.924327 -1.216093  -0.954960 -1.430586 -0.677749 -1.241267
# 1  0.620473 -0.106454  0.000814   0.394268 -0.053221 -0.455661 -0.365077
# 2  0.629958 -0.463236  0.374776   2.667647  0.197904  0.369329  0.117043
# 3 -0.947316 -0.369223 -1.855211   0.008938 -1.193723 -0.241701 -1.592346
# 4 -0.390734 -1.194300  1.469549   0.334271  0.010829 -1.216269  2.068787
# 5 -0.117969 -0.817358 -0.585631  -0.151411 -0.820633 -0.982623 -0.811160
# 6 -1.099605 -0.809072 -1.290658  -0.465442 -0.841476 -0.375878 -0.818319
# 7 -0.463009 -0.080461 -0.646334   0.315845  0.352504 -0.231065  0.374733
# 8  1.064322  1.383170  0.067417   2.329629  1.139121  1.508058  0.028182
# 9 -1.444955 -1.191689 -1.730779  -0.667059 -1.037205 -1.129968 -1.812281
#
#    mean1HF_D  std1HF_D  class
# 0  -1.650076 -1.101028    1.0
# 1   0.624007 -0.406974    1.0
# 2   0.175168  0.880377    1.0
# 3   1.884758 -1.388342    1.0
# 4  -0.747074 -0.608417    1.0
# 5   0.983455 -0.991928    1.0
# 6  -1.508644 -0.052608    1.0
# 7  -1.343813 -0.537419    1.0
# 8   0.351560  1.599582    0.0
# 9  -0.715996 -1.296585    1.0
#
# [10 rows x 31 columns]

# %%
x_train = training_set.loc[:, training_set.columns != 'class'].to_numpy()
y_train = np.squeeze(training_set.loc[:, training_set.columns == 'class'].to_numpy())
x_test = test_set.loc[:, test_set.columns != 'class'].to_numpy()
y_test = np.squeeze(test_set.loc[:, test_set.columns == 'class'].to_numpy())

# %% [markdown]
# # Logistic classifier

# %%
log = Logistic(hyperparams=[0.01, 0.001])

# %% [markdown]
# #### Cross-Validation:

# %%
log.train(x_train, y_train, tuning=True)
print(log)
# Out:
# Tuple testé: [0.0001, 0.1]
# Error moyenne:  7.277585691445114
# Tuple meilleur! On change pour:[0.0001, 0.1] et une erreur moyenne de 7.277585691445114
# Tuple testé: [0.001, 0.1]
# Error moyenne:  4.3322280032679465
# Tuple meilleur! On change pour:[0.001, 0.1] et une erreur moyenne de 4.3322280032679465
# Tuple testé: [0.01, 0.1]
# Error moyenne:  4.015274625603942
# Tuple meilleur! On change pour:[0.01, 0.1] et une erreur moyenne de 4.015274625603942
# Tuple testé: [0.1, 0.1]
# Error moyenne:  4.253017025570875
# Tuple testé: [0.0001, 0.2]
# Error moyenne:  6.854933283394421
# Tuple testé: [0.001, 0.2]
# Error moyenne:  4.398269563328801
# Tuple testé: [0.01, 0.2]
# Error moyenne:  4.649264245522231
# Tuple testé: [0.1, 0.2]
# Error moyenne:  5.243633087922192
# Tuple testé: [0.0001, 0.5]
# Error moyenne:  6.656814718679774
# Tuple testé: [0.001, 0.5]
# Error moyenne:  4.794523510294866
# Tuple testé: [0.01, 0.5]
# Error moyenne:  5.6398931503561744
# Tuple testé: [0.1, 0.5]
# Error moyenne:  5.52102103305252
# Tuple testé: [0.0001, 1]
# Error moyenne:  6.854937258448568
# Tuple testé: [0.001, 1]
# Error moyenne:  5.2832416345046855
# Tuple testé: [0.01, 1]
# Error moyenne:  6.722978588098977
# Tuple testé: [0.1, 1]
# Error moyenne:  6.947514266075399
# Tuple testé: [0.0001, 2]
# Error moyenne:  7.039847878079117
# Tuple testé: [0.001, 2]
# Error moyenne:  5.230429423665638
# Tuple testé: [0.01, 2]
# Error moyenne:  7.832486031477889
# Tuple testé: [0.1, 2]
# Error moyenne:  8.043814681690401
# Les hyperamètres sont:
# lr:0.01
# alpha:0.1

# %% [markdown]
# #### Test plotting learning curves:
# Plot les courbes d'apprentissages et utilise une cross-validation pour vérifier les paramètres du modèle. La fonction prend en entrée l'objet sans entraînement et init plusieurs fois l'objet avec les bons paramètres.

# %%
log.reinit()
plot_learning_curve(log.logistic_classifier, 
                    "Logistic classifier",x_train, y_train, 
                    train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# #### Matrice de confusion avec les meilleurs paramètres:

# %%
log.train(x_train, y_train, tuning=False)
confusion_matrix = pd.DataFrame(log.get_confusion_matrix(x_test, y_test))
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.719551282051282%
#    Prédit normal  Prédit malade
# 0       0.149038       0.225962
# 1       0.054487       0.570513

# %% [markdown]
# ### Courbes ROC et précision-rappel:
# Pour rappel:
# - La ROC correspond aux taux de vrais positifs (pneumonia bien détectée) en fonction du taux de faux positifs (taux de normal détecté comme pneuomia)
# - La précision-rappel correspond à la précision (nombre de pneumonies détectées par rapport aux nombre de pneumonia réelles détectées + nombres de pneumonie fausses détectées (en gros le nombre de pneumonie bien detectées par rapport à tout ce qu'il a detecté)) en fonction du rappel (ou sensibilité: nombre de pneumonie détectées sur le nombres de pneumonies réelles détectées + les pneumonies réelles non détectées)

# %%
roc, pres_rec = log.get_curves(x_test, y_test)

# %% [markdown]
# # Adaboost:

# %%
ada = Adaboost([0.1])

# %%
# Cross-validation !!!!
# ada.train(x_train, y_train, tuning=True)

# %%
ada.train(x_train, y_train, tuning=False)
confusion_matrix = pd.DataFrame(ada.get_confusion_matrix(x_test, y_test))
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7275641025641025%
#    Prédit normal  Prédit malade
# 0       0.171474       0.203526
# 1       0.068910       0.556090

# %%
roc, pres_rec = ada.get_curves(x_test, y_test)

# %%
ada.reinit()
plot_learning_curve(ada.adaboost_classifier, "Adaboost",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # Multi-Layer Perceptron

# %%
mlp = Mlp([10, 0.1, 0.1])

# %%
mlp.train(x_train, y_train, tuning=True)
# Out:
# Tuple testé: [2, 0.9, 0.001]
# [2, 0.9, 0.001]
# [2, 0.9, 0.001]
# Error moyenne:  10.863732819942673
# Tuple meilleur! On change pour:[2, 0.9, 0.001] et une erreur moyenne de 10.863732819942673
# Tuple testé: [10, 0.9, 0.001]
# [10, 0.9, 0.001]
# [10, 0.9, 0.001]
# Error moyenne:  8.882415690235987
# Tuple meilleur! On change pour:[10, 0.9, 0.001] et une erreur moyenne de 8.882415690235987
# Tuple testé: [30, 0.9, 0.001]
# [30, 0.9, 0.001]
# [30, 0.9, 0.001]
# Error moyenne:  9.839956544892411
# Tuple testé: [60, 0.9, 0.001]
# [60, 0.9, 0.001]
# [60, 0.9, 0.001]
# Error moyenne:  6.141737272379999
# Tuple meilleur! On change pour:[60, 0.9, 0.001] et une erreur moyenne de 6.141737272379999
# Tuple testé: [100, 0.9, 0.001]
# [100, 0.9, 0.001]
# [100, 0.9, 0.001]
# Error moyenne:  5.514378227289197
# Tuple meilleur! On change pour:[100, 0.9, 0.001] et une erreur moyenne de 5.514378227289197
# Tuple testé: [2, 0.7, 0.001]
# [2, 0.7, 0.001]
# [2, 0.7, 0.001]
# Error moyenne:  12.679795456099757
# Tuple testé: [10, 0.7, 0.001]
# [10, 0.7, 0.001]
# [10, 0.7, 0.001]
# Error moyenne:  18.821392072717654
# Tuple testé: [30, 0.7, 0.001]
# [30, 0.7, 0.001]
# [30, 0.7, 0.001]
# Error moyenne:  8.122937443762764
# Tuple testé: [60, 0.7, 0.001]
# [60, 0.7, 0.001]
# [60, 0.7, 0.001]
# Error moyenne:  7.594628049167316
# Tuple testé: [100, 0.7, 0.001]
# [100, 0.7, 0.001]
# [100, 0.7, 0.001]
# Error moyenne:  4.95302297924486
# Tuple meilleur! On change pour:[100, 0.7, 0.001] et une erreur moyenne de 4.95302297924486
# Tuple testé: [2, 0.5, 0.001]
# [2, 0.5, 0.001]
# [2, 0.5, 0.001]
# Error moyenne:  18.55722629113433
# Tuple testé: [10, 0.5, 0.001]
# [10, 0.5, 0.001]
# [10, 0.5, 0.001]
# Error moyenne:  12.481657933434567
# Tuple testé: [30, 0.5, 0.001]
# [30, 0.5, 0.001]
# [30, 0.5, 0.001]
# Error moyenne:  7.429534086650547
# Tuple testé: [60, 0.5, 0.001]
# [60, 0.5, 0.001]
# [60, 0.5, 0.001]
# Error moyenne:  5.4483102178296
# Tuple testé: [100, 0.5, 0.001]
# [100, 0.5, 0.001]
# [100, 0.5, 0.001]
# Error moyenne:  5.316235353589579
# Tuple testé: [2, 0.2, 0.001]
# [2, 0.2, 0.001]
# [2, 0.2, 0.001]
# Error moyenne:  19.151652618932715
# Tuple testé: [10, 0.2, 0.001]
# [10, 0.2, 0.001]
# [10, 0.2, 0.001]
# Error moyenne:  12.184369855053387
# Tuple testé: [30, 0.2, 0.001]
# [30, 0.2, 0.001]
# [30, 0.2, 0.001]
# Error moyenne:  6.571058935592756
# Tuple testé: [60, 0.2, 0.001]
# [60, 0.2, 0.001]
# [60, 0.2, 0.001]
# Error moyenne:  5.646433980691976
# Tuple testé: [100, 0.2, 0.001]
# [100, 0.2, 0.001]
# [100, 0.2, 0.001]
# Error moyenne:  4.986029082152285
# Tuple testé: [2, 0.9, 0.1]
# [2, 0.9, 0.1]
# [2, 0.9, 0.1]
# Error moyenne:  17.236469239965736
# Tuple testé: [10, 0.9, 0.1]
# [10, 0.9, 0.1]
# [10, 0.9, 0.1]
# Error moyenne:  12.811735015612104
# Tuple testé: [30, 0.9, 0.1]
# [30, 0.9, 0.1]
# [30, 0.9, 0.1]
# Error moyenne:  7.792731172325471
# Tuple testé: [60, 0.9, 0.1]
# [60, 0.9, 0.1]
# [60, 0.9, 0.1]
# Error moyenne:  6.207766295731622
# Tuple testé: [100, 0.9, 0.1]
# [100, 0.9, 0.1]
# [100, 0.9, 0.1]
# Error moyenne:  5.382285016645424
# Tuple testé: [2, 0.7, 0.1]
# [2, 0.7, 0.1]
# [2, 0.7, 0.1]
# Error moyenne:  15.420469287354805
# Tuple testé: [10, 0.7, 0.1]
# [10, 0.7, 0.1]
# [10, 0.7, 0.1]
# Error moyenne:  15.98170834150871
# Tuple testé: [30, 0.7, 0.1]
# [30, 0.7, 0.1]
# [30, 0.7, 0.1]
# Error moyenne:  7.594616582664971
# Tuple testé: [60, 0.7, 0.1]
# [60, 0.7, 0.1]
# [60, 0.7, 0.1]
# Error moyenne:  8.288017646476721
# Tuple testé: [100, 0.7, 0.1]
# [100, 0.7, 0.1]
# [100, 0.7, 0.1]
# Error moyenne:  4.820934355202025
# Tuple meilleur! On change pour:[100, 0.7, 0.1] et une erreur moyenne de 4.820934355202025
# Tuple testé: [2, 0.5, 0.1]
# [2, 0.5, 0.1]
# [2, 0.5, 0.1]
# Error moyenne:  12.481550912746012
# Tuple testé: [10, 0.5, 0.1]
# [10, 0.5, 0.1]
# [10, 0.5, 0.1]
# Error moyenne:  8.750324772892682
# Tuple testé: [30, 0.5, 0.1]
# [30, 0.5, 0.1]
# [30, 0.5, 0.1]
# Error moyenne:  6.372878604652145
# Tuple testé: [60, 0.5, 0.1]
# [60, 0.5, 0.1]
# [60, 0.5, 0.1]
# Error moyenne:  5.844576089958104
# Tuple testé: [100, 0.5, 0.1]
# [100, 0.5, 0.1]
# [100, 0.5, 0.1]
# Error moyenne:  5.976624963459476
# Tuple testé: [2, 0.2, 0.1]
# [2, 0.2, 0.1]
# [2, 0.2, 0.1]
# Error moyenne:  15.55253650725993
# Tuple testé: [10, 0.2, 0.1]
# [10, 0.2, 0.1]
# [10, 0.2, 0.1]
# Error moyenne:  10.566400404419092
# Tuple testé: [30, 0.2, 0.1]
# [30, 0.2, 0.1]
# [30, 0.2, 0.1]
# Error moyenne:  5.745518030694364
# Tuple testé: [60, 0.2, 0.1]
# [60, 0.2, 0.1]
# [60, 0.2, 0.1]
# Error moyenne:  6.339866386276802
# Tuple testé: [100, 0.2, 0.1]
# [100, 0.2, 0.1]
# [100, 0.2, 0.1]
# Error moyenne:  4.853951160178306
# Tuple testé: [2, 0.9, 0.5]
# [2, 0.9, 0.5]
# [2, 0.9, 0.5]
# Error moyenne:  10.467375980228898
# Tuple testé: [10, 0.9, 0.5]
# [10, 0.9, 0.5]
# [10, 0.9, 0.5]
# Error moyenne:  8.122990189673551
# Tuple testé: [30, 0.9, 0.5]
# [30, 0.9, 0.5]
# [30, 0.9, 0.5]
# Error moyenne:  11.028654020490777
# Tuple testé: [60, 0.9, 0.5]
# [60, 0.9, 0.5]
# [60, 0.9, 0.5]
# Error moyenne:  5.217165063390004
# Tuple testé: [100, 0.9, 0.5]
# [100, 0.9, 0.5]
# [100, 0.9, 0.5]
# Error moyenne:  5.745490511088736
# Tuple testé: [2, 0.7, 0.5]
# [2, 0.7, 0.5]
# [2, 0.7, 0.5]
# Error moyenne:  17.632775627069194
# Tuple testé: [10, 0.7, 0.5]
# [10, 0.7, 0.5]
# [10, 0.7, 0.5]
# Error moyenne:  8.486185746481496
# Tuple testé: [30, 0.7, 0.5]
# [30, 0.7, 0.5]
# [30, 0.7, 0.5]
# Error moyenne:  7.759724304984555
# Tuple testé: [60, 0.7, 0.5]
# [60, 0.7, 0.5]
# [60, 0.7, 0.5]
# Error moyenne:  5.118112355160692
# Tuple testé: [100, 0.7, 0.5]
# [100, 0.7, 0.5]
# [100, 0.7, 0.5]
# Error moyenne:  4.721876295938285
# Tuple meilleur! On change pour:[100, 0.7, 0.5] et une erreur moyenne de 4.721876295938285
# Tuple testé: [2, 0.5, 0.5]
# [2, 0.5, 0.5]
# [2, 0.5, 0.5]
# Error moyenne:  8.123074277357414
# Tuple testé: [10, 0.5, 0.5]
# [10, 0.5, 0.5]
# [10, 0.5, 0.5]
# Error moyenne:  11.028735814874171
# Tuple testé: [30, 0.5, 0.5]
# [30, 0.5, 0.5]
# [30, 0.5, 0.5]
# Error moyenne:  5.811521063307339
# Tuple testé: [60, 0.5, 0.5]
# [60, 0.5, 0.5]
# [60, 0.5, 0.5]
# Error moyenne:  5.6134225267501225
# Tuple testé: [100, 0.5, 0.5]
# [100, 0.5, 0.5]
# [100, 0.5, 0.5]
# Error moyenne:  5.2501956281691005
# Tuple testé: [2, 0.2, 0.5]
# [2, 0.2, 0.5]
# [2, 0.2, 0.5]
# Error moyenne:  11.557056675971966
# Tuple testé: [10, 0.2, 0.5]
# [10, 0.2, 0.5]
# [10, 0.2, 0.5]
# Error moyenne:  17.665693820125306
# Tuple testé: [30, 0.2, 0.5]
# [30, 0.2, 0.5]
# [30, 0.2, 0.5]
# Error moyenne:  6.537975624902874
# Tuple testé: [60, 0.2, 0.5]
# [60, 0.2, 0.5]
# [60, 0.2, 0.5]
# Error moyenne:  6.5710038963815
# Tuple testé: [100, 0.2, 0.5]
# [100, 0.2, 0.5]
# [100, 0.2, 0.5]
# Error moyenne:  5.052071100873235
# [100, 0.7, 0.5]

# %%
print(mlp)
# Out:
# Les hyperamètres sont:
# hidden_layer_sizes:100
# alpha:0.7
# momentum:0.5

# %%
mlp.train(x_train, y_train, tuning=False)
confusion_matrix = pd.DataFrame(mlp.get_confusion_matrix(x_test, y_test))
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# [100, 0.7, 0.5]
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.717948717948718%
#    Prédit normal  Prédit malade
# 0       0.168269       0.206731
# 1       0.075321       0.549679

# %%
mlp.reinit()
plot_learning_curve(mlp.mlp, "Adaboost",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))
