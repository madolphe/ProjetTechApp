# %% [markdown]
# # Technique d'apprentissage

# %% [markdown]
# ### Visualisation des données

# %%
import numpy as np
from models.logistic_reg import Logistic
from models.adaboost import Adaboost
from models.mlp import Mlp
from models.svm import Svm
from models.decision_tree import Forest
from models.model_mixture import ModelMixture
import pandas as pd
from utils import plot_learning_curve
import warnings
from get_data.get_dataset import training_set, test_set
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ### Visualisation du jeu de données
# On choisit de mélanger nos données et d'afficher les 10 premières lignes du jeu d'entraînement.

# %%
training_set = training_set.sample(frac=1).reset_index(drop=True)
training_set.head(10)
# Out:
#    contrast_0  contrast_45  contrast_90  contrast_135  correlation_0  \
# 0   -1.817944    -1.627173    -1.358152     -1.710709      -0.067340
# 1   -1.159089    -1.182972    -1.128047     -1.261151       0.795749
# 2   -0.125967    -0.164362     0.127271      0.124171       1.425914
# 3   -1.190247    -1.206166    -1.023433     -1.144291       0.495245
# 4   -0.352274    -0.357661    -0.421357     -0.383854       0.951339
# 5   -1.425283    -1.248266    -0.886367     -1.215000       0.458846
# 6   -0.635725    -0.412444    -0.308697     -0.585640       0.736183
# 7   -0.589524    -0.779775    -0.831622     -0.691336      -2.977805
# 8   -1.193643    -1.147895    -0.701612     -0.989837       0.453044
# 9   -0.832694    -0.988414    -0.970178     -0.922441      -1.427396
#
#    correlation_45  correlation_90  correlation_135  energy_0  energy_45  ...  \
# 0       -0.036867        0.325288         0.179654 -0.658752  -0.678595  ...
# 1        0.963724        1.067459         1.065504 -0.432802  -0.479120  ...
# 2        1.429947        0.914279         1.237321  1.611472   1.607935  ...
# 3        0.686564        0.710069         0.606811 -0.162411  -0.138712  ...
# 4        0.961417        0.874665         0.984529  0.307713   0.314192  ...
# 5        0.407311        0.220900         0.366805 -0.704923  -0.718875  ...
# 6        0.548062        0.381965         0.731763 -0.738939  -0.765461  ...
# 7       -2.359571       -1.262600        -2.572558 -0.764598  -0.783908  ...
# 8        0.552346        0.186573         0.331187 -0.590878  -0.658474  ...
# 9       -0.949340       -0.288356        -1.074574 -0.759436  -0.745462  ...
#
#    std3HF_D  std2HF_H  std2HF_V  mean2HF_D  std2HF_D  std1HF_H  std1HF_V  \
# 0 -1.032382 -1.394144 -1.474636  -0.492612 -1.178969 -1.669273 -1.541503
# 1 -0.918600 -1.410654 -0.399980   0.199563 -1.190571 -1.411968 -0.085933
# 2 -0.488918  0.236833 -0.626822  -0.871339  0.327692  0.407886 -0.273331
# 3 -0.598131 -1.095941 -1.704426   0.816500 -0.892255 -1.138902 -1.180692
# 4 -0.012378 -0.758714 -0.390392  -1.349727 -0.857646 -1.041168 -0.853584
# 5 -0.612081 -0.708785 -1.413553  -0.295356 -1.297684 -0.712079 -1.481962
# 6 -0.446910 -0.353529 -0.615959  -0.196728 -0.374974 -0.393868 -0.764761
# 7 -0.689189 -1.135577 -0.233192   0.318049 -0.867272 -1.385605  0.250851
# 8 -1.264901  0.023341 -1.553880  -0.038907 -0.785841  0.462427 -1.029832
# 9 -1.254491 -1.037178 -0.743454   0.868739 -0.690259 -1.143192 -0.347445
#
#    mean1HF_D  std1HF_D  class
# 0   0.832920 -1.875962    1.0
# 1  -1.741366 -1.137175    1.0
# 2   1.699554  0.465531    1.0
# 3   0.007005 -0.893715    1.0
# 4  -0.058950 -0.897285    1.0
# 5  -0.725524 -0.982222    1.0
# 6  -0.443337 -0.301922    1.0
# 7   1.522750 -0.799893    1.0
# 8   0.225587 -0.575334    1.0
# 9  -0.020520 -0.782140    1.0
#
# [10 rows x 31 columns]

# %% [markdown]
# On sépare nos données en jeu de test et d'entraînement.

# %%
x_train = training_set.loc[:, training_set.columns != 'class'].to_numpy()
y_train = np.squeeze(training_set.loc[:, training_set.columns == 'class'].to_numpy())
x_test = test_set.loc[:, test_set.columns != 'class'].to_numpy()
y_test = np.squeeze(test_set.loc[:, test_set.columns == 'class'].to_numpy())

# %% [markdown]
# # Logistic classifier

# %%
log = Logistic(hyperparams=[0.01, 0.001])

# %% [markdown]
# #### Cross-Validation:

# %%
log.train(x_train, y_train, tuning=True)
print(log)
# Out:
# Tuple testé: [0.0001, 0.1]
# Error moyenne:  6.815309142368737
# Tuple meilleur! On change pour:[0.0001, 0.1] et une erreur moyenne de 6.815309142368737
# Tuple testé: [0.001, 0.1]
# Error moyenne:  5.085082707701785
# Tuple meilleur! On change pour:[0.001, 0.1] et une erreur moyenne de 5.085082707701785
# Tuple testé: [0.01, 0.1]
# Error moyenne:  4.437930702935384
# Tuple meilleur! On change pour:[0.01, 0.1] et une erreur moyenne de 4.437930702935384
# Tuple testé: [0.1, 0.1]
# Error moyenne:  4.451141399980043
# Tuple testé: [0.0001, 0.2]
# Error moyenne:  7.092677212228334
# Tuple testé: [0.001, 0.2]
# Error moyenne:  4.556772242899451
# Tuple testé: [0.01, 0.2]
# Error moyenne:  4.741721389977881
# Tuple testé: [0.1, 0.2]
# Error moyenne:  4.675683499197778
# Tuple testé: [0.0001, 0.5]
# Error moyenne:  7.053052765429254
# Tuple testé: [0.001, 0.5]
# Error moyenne:  5.085094327090828
# Tuple testé: [0.01, 0.5]
# Error moyenne:  5.1379805350916765
# Tuple testé: [0.1, 0.5]
# Error moyenne:  6.141802402113319
# Tuple testé: [0.0001, 1]
# Error moyenne:  6.5907768278996715
# Tuple testé: [0.001, 1]
# Error moyenne:  5.230404350247177
# Tuple testé: [0.01, 1]
# Error moyenne:  6.53806552228126
# Tuple testé: [0.1, 1]
# Error moyenne:  6.419186983736291
# Tuple testé: [0.0001, 2]
# Error moyenne:  6.366239315282874
# Tuple testé: [0.001, 2]
# Error moyenne:  6.39274663169643
# Tuple testé: [0.01, 2]
# Error moyenne:  7.673980905720069
# Tuple testé: [0.1, 2]
# Error moyenne:  8.057022626774497
# Les hyperamètres sont:
# lr:0.01
# alpha:0.1

# %% [markdown]
# #### Performance du modèle:
# La métrique utilisé ci-dessous sera réutilisée à l'identique pour l'ensemble des solutions testées dans ce notebook.
#
# On affiche les courbes d'apprentissages pour différentes tailles de sous-ensembles d'entraînement. A chaque entraînement on récupère aussi une précision moyenne sur une 5-fold cross-validation.
# Cette première courbe permet de vérifier la robustesse du modèle vis-à-vis de tailles d'ensembles d'entraînements différents.
# De plus on affiche l'adaptibilité du modèle. C'est à dire le temps d'inférence pour un nombre de données fixé.
# Pour finir on affiche la performance du modèle en fonction du temps d'entraînement.

# %%
log.reinit()
plot_learning_curve(log.logistic_classifier, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# #### Matrice de confusion avec les meilleurs paramètres:
#
# On affiche ici la matrice de confusion, c'est à dire le taux de vrai positifs, faux positifs, faux négatifs, vrai négatifs.
# On affiche aussi la justesse c'est à dire le nombre total de données bien classées sur notre ensemble de test.

# %%
log.train(x_train, y_train, tuning=False)
justesse_log, confusion_matrix = log.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7067307692307693%
#    Prédit normal  Prédit malade
# 0       0.129808       0.245192
# 1       0.048077       0.576923

# %% [markdown]
# ### Courbes ROC et précision-rappel:
# Pour rappel:
# - La ROC correspond aux taux de vrais positifs (pneumonie bien détectée) en fonction du taux de faux positifs (taux de (patient)normaux détectés comme ayant une pneumonie)
# - La précision-rappel correspond à la précision (nombre de pneumonies détectées par rapport aux nombre de pneumonies réelles détectées + nombre de pneumonies fausses détectées (i.e le nombre de pneumonies bien detectées par rapport à tout ce que le modèle a detecté) en fonction du rappel (ou sensibilité: nombre de pneumonies détectées sur le nombre de pneumonies réelles détectées + les pneumonies réelles non détectées)

# %%
roc_log, pres_rec_log = log.get_curves(x_test, y_test)

# %% [markdown]
# # Adaboost:

# %%
ada = Adaboost([0.1])

# %%
# Cross-validation !!!!
ada.train(x_train, y_train, tuning=True)
print(ada)
# Out:
# Tuple testé: [1]
# Error moyenne:  0.10592734225621414
# Tuple meilleur! On change pour:[1] et une erreur moyenne de 0.10592734225621414
# Tuple testé: [0.1]
# Error moyenne:  0.1349904397705545
# Tuple testé: [0.001]
# Error moyenne:  0.16443594646271512
# Tuple testé: [0.0001]
# Error moyenne:  0.16061185468451242
# Estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=1, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
# Les hyperamètres sont:
# lr:1

# %%
ada.train(x_train, y_train, tuning=False)
justesse_ada, confusion_matrix = ada.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.719551282051282%
#    Prédit normal  Prédit malade
# 0       0.149038       0.225962
# 1       0.054487       0.570513

# %%
roc_ada, pres_rec_ada = ada.get_curves(x_test, y_test)

# %%
ada.reinit()
plot_learning_curve(ada.adaboost_classifier, "Adaboost",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # Multi-Layer Perceptron

# %%
mlp = Mlp([10, 0.1, 0.1])

# %%
# Cross-validation !!!!
mlp.train(x_train, y_train, tuning=True)
print(mlp)
# Out:
# Tuple testé: [2, 0.9, 0.001]
# Error moyenne:  12.778722797236762
# Tuple meilleur! On change pour:[2, 0.9, 0.001] et une erreur moyenne de 12.778722797236762
# Tuple testé: [10, 0.9, 0.001]
# Error moyenne:  7.066349996344945
# Tuple meilleur! On change pour:[10, 0.9, 0.001] et une erreur moyenne de 7.066349996344945
# Tuple testé: [30, 0.9, 0.001]
# Error moyenne:  6.141769378586565
# Tuple meilleur! On change pour:[30, 0.9, 0.001] et une erreur moyenne de 6.141769378586565
# Tuple testé: [60, 0.9, 0.001]
# Error moyenne:  6.2408014471116555
# Tuple testé: [100, 0.9, 0.001]
# Error moyenne:  5.052089447276986
# Tuple meilleur! On change pour:[100, 0.9, 0.001] et une erreur moyenne de 5.052089447276986
# Tuple testé: [2, 0.7, 0.001]
# Error moyenne:  11.755191140903197
# Tuple testé: [10, 0.7, 0.001]
# Error moyenne:  10.170245375146589
# Tuple testé: [30, 0.7, 0.001]
# Error moyenne:  8.45313530643167
# Tuple testé: [60, 0.7, 0.001]
# Error moyenne:  6.207757122529746
# Tuple testé: [100, 0.7, 0.001]
# Error moyenne:  5.250194099302121
# Tuple testé: [2, 0.5, 0.001]
# Error moyenne:  14.925094903352244
# Tuple testé: [10, 0.5, 0.001]
# Error moyenne:  10.863689247233761
# Tuple testé: [30, 0.5, 0.001]
# Error moyenne:  8.849346139348919
# Tuple testé: [60, 0.5, 0.001]
# Error moyenne:  5.08510166565233
# Tuple testé: [100, 0.5, 0.001]
# Error moyenne:  5.085099372351861
# Tuple testé: [2, 0.2, 0.001]
# Error moyenne:  16.37789471255429
# Tuple testé: [10, 0.2, 0.001]
# Error moyenne:  9.774018489126059
# Tuple testé: [30, 0.2, 0.001]
# Error moyenne:  7.726690682471501
# Tuple testé: [60, 0.2, 0.001]
# Error moyenne:  6.108728111738614
# Tuple testé: [100, 0.2, 0.001]
# Error moyenne:  4.622810592339649
# Tuple meilleur! On change pour:[100, 0.2, 0.001] et une erreur moyenne de 4.622810592339649
# Tuple testé: [2, 0.9, 0.1]
# Error moyenne:  14.132607496237638
# Tuple testé: [10, 0.9, 0.1]
# Error moyenne:  10.33529652938794
# Tuple testé: [30, 0.9, 0.1]
# Error moyenne:  12.250396585104541
# Tuple testé: [60, 0.9, 0.1]
# Error moyenne:  5.976621141292028
# Tuple testé: [100, 0.9, 0.1]
# Error moyenne:  5.184142907379297
# Tuple testé: [2, 0.7, 0.1]
# Error moyenne:  17.302497498883874
# Tuple testé: [10, 0.7, 0.1]
# Error moyenne:  16.113731224271437
# Tuple testé: [30, 0.7, 0.1]
# Error moyenne:  8.221974863322284
# Tuple testé: [60, 0.7, 0.1]
# Error moyenne:  6.240821322382386
# Tuple testé: [100, 0.7, 0.1]
# Error moyenne:  5.679454607835705
# Tuple testé: [2, 0.5, 0.1]
# Error moyenne:  25.92059222753813
# Tuple testé: [10, 0.5, 0.1]
# Error moyenne:  9.476796152024992
# Tuple testé: [30, 0.5, 0.1]
# Error moyenne:  10.170155936428298
# Tuple testé: [60, 0.5, 0.1]
# Error moyenne:  9.245611247043932
# Tuple testé: [100, 0.5, 0.1]
# Error moyenne:  4.68884878889315
# Tuple testé: [2, 0.2, 0.1]
# Error moyenne:  9.774094932475027
# Tuple testé: [10, 0.2, 0.1]
# Error moyenne:  12.943804528817699
# Tuple testé: [30, 0.2, 0.1]
# Error moyenne:  5.580384317636131
# Tuple testé: [60, 0.2, 0.1]
# Error moyenne:  5.448314039997047
# Tuple testé: [100, 0.2, 0.1]
# Error moyenne:  5.283209375411422
# Tuple testé: [2, 0.9, 0.5]
# Error moyenne:  21.13281991967542
# Tuple testé: [10, 0.9, 0.5]
# Error moyenne:  10.731515771073575
# Tuple testé: [30, 0.9, 0.5]
# Error moyenne:  10.863595221914531
# Tuple testé: [60, 0.9, 0.5]
# Error moyenne:  4.589812898200611
# Tuple meilleur! On change pour:[60, 0.9, 0.5] et une erreur moyenne de 4.589812898200611
# Tuple testé: [100, 0.9, 0.5]
# Error moyenne:  5.085094021317433
# Tuple testé: [2, 0.7, 0.5]
# Error moyenne:  14.694034601030005
# Tuple testé: [10, 0.7, 0.5]
# Error moyenne:  12.7126891872842
# Tuple testé: [30, 0.7, 0.5]
# Error moyenne:  6.703066529685686
# Tuple testé: [60, 0.7, 0.5]
# Error moyenne:  5.943629562620905
# Tuple testé: [100, 0.7, 0.5]
# Error moyenne:  5.0520733941737035
# Tuple testé: [2, 0.5, 0.5]
# Error moyenne:  23.675322593191737
# Tuple testé: [10, 0.5, 0.5]
# Error moyenne:  8.585267503183417
# Tuple testé: [30, 0.5, 0.5]
# Error moyenne:  6.703094049291314
# Tuple testé: [60, 0.5, 0.5]
# Error moyenne:  7.198369056940219
# Tuple testé: [100, 0.5, 0.5]
# Error moyenne:  5.151133746737912
# Tuple testé: [2, 0.2, 0.5]
# Error moyenne:  12.18435762411755
# Tuple testé: [10, 0.2, 0.5]
# Error moyenne:  9.212657890047295
# Tuple testé: [30, 0.2, 0.5]
# Error moyenne:  7.330477556253785
# Tuple testé: [60, 0.2, 0.5]
# Error moyenne:  6.7030535343163615
# Tuple testé: [100, 0.2, 0.5]
# Error moyenne:  5.349268976102632
# Les hyperamètres sont:
# hidden_layer_sizes:60
# alpha:0.9
# momentum:0.5

# %%
justesse_mlp, confusion_matrix = mlp.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
confusion_matrix.head()
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7339743589743589%
#    Prédit normal  Prédit malade
# 0       0.192308       0.182692
# 1       0.083333       0.541667

# %%
roc_mlp, pres_rec_mlp = mlp.get_curves(x_test, y_test)

# %%
mlp.reinit()
plot_learning_curve(mlp.mlp, "multi layer perceptron",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # SVM

# %%
svmrbf = Svm('rbf', ['gamma', 'régularisation'],[100,0.0001])
svmlinear = Svm('linear', ['None'],[])
svmpolynomial = Svm('poly', ['degree'],[1])

# %%
svmrbf.train(x_train, y_train, tuning=True)
svmlinear.train(x_train, y_train, tuning=True)
svmpolynomial.train(x_train, y_train, tuning=True)
print(svmrbf)

print(svmpolynomial)
# Out:
# Tuple testé: [1, 0.001]
# Error moyenne:  0.3537284894837476
# Tuple meilleur! On change pour:[1, 0.001] et une erreur moyenne de 0.3537284894837476
# Tuple testé: [10, 0.001]
# Error moyenne:  0.3365200764818356
# Tuple meilleur! On change pour:[10, 0.001] et une erreur moyenne de 0.3365200764818356
# Tuple testé: [100, 0.001]
# Error moyenne:  0.36806883365200765
# Tuple testé: [1000, 0.001]
# Error moyenne:  0.32217973231357555
# Tuple meilleur! On change pour:[1000, 0.001] et une erreur moyenne de 0.32217973231357555
# Tuple testé: [1, 0.0001]
# Error moyenne:  0.4024856596558317
# Tuple testé: [10, 0.0001]
# Error moyenne:  0.3460803059273423
# Tuple testé: [100, 0.0001]
# Error moyenne:  0.33078393881453155
# Tuple testé: [1000, 0.0001]
# Error moyenne:  0.3546845124282983
# Tuple testé: [1]
# Error moyenne:  0.33078393881453155
# Tuple meilleur! On change pour:[1] et une erreur moyenne de 0.33078393881453155
# Tuple testé: [2]
# Error moyenne:  0.38718929254302104
# Tuple testé: [3]
# Error moyenne:  0.378585086042065
# Tuple testé: [4]
# Error moyenne:  0.41778202676864246
# Tuple testé: [5]
# Error moyenne:  0.4598470363288719
# Tuple testé: [6]
# Error moyenne:  0.43021032504780116
# Tuple testé: [7]
# Error moyenne:  0.4168260038240918
# Tuple testé: [8]
# Error moyenne:  0.4034416826003824
# Tuple testé: [9]
# Error moyenne:  0.39961759082217974
# Tuple testé: [10]
# Error moyenne:  0.43690248565965584
# Les hyperamètres sont:
# gamma:1000
# régularisation:0.001
#
# Les hyperamètres sont:
# degree:1

# %%
justesse_svmrbf, confusion_matrix = svmrbf.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())

justesse_linear, confusion_matrix = svmlinear.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())

justesse_svmpoly, confusion_matrix = svmpolynomial.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7355769230769231%
#    Prédit normal  Prédit malade
# 0       0.153846       0.221154
# 1       0.043269       0.581731
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7147435897435898%
#    Prédit normal  Prédit malade
# 0       0.141026       0.233974
# 1       0.051282       0.573718
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7147435897435898%
#    Prédit normal  Prédit malade
# 0       0.144231       0.230769
# 1       0.054487       0.570513

# %%
roc_svmrbf, pres_rec_svmrbf = svmrbf.get_curves(x_test, y_test)
roc_svmlinear, pres_rec_svmlinear = svmlinear.get_curves(x_test, y_test)
roc_poly, pres_rec_poly = svmpolynomial.get_curves(x_test, y_test)

# %%
svmrbf.reinit()
plot_learning_curve(svmrbf.model, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %%
svmlinear.reinit()
plot_learning_curve(svmlinear.model, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %%
svmpolynomial.reinit()
plot_learning_curve(svmpolynomial.model, "Logistic classifier",x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # Decision Tree

# %%
# ['max_depth', 'min_samples_leaf,min_samples_split,n_estimators']
forest = Forest([10, 3, 5, 200])

# %%
forest.train(x_train, y_train, tuning=True)
print(forest)
# Out:
# Tuple testé: [10, 2, 2, 200]
# Error moyenne:  0.10038240917782026
# Tuple meilleur! On change pour:[10, 2, 2, 200] et une erreur moyenne de 0.10038240917782026
# Tuple testé: [20, 2, 2, 200]
# Error moyenne:  0.07839388145315487
# Tuple meilleur! On change pour:[20, 2, 2, 200] et une erreur moyenne de 0.07839388145315487
# Tuple testé: [10, 3, 2, 200]
# Error moyenne:  0.09273422562141492
# Tuple testé: [20, 3, 2, 200]
# Error moyenne:  0.09082217973231357
# Tuple testé: [10, 2, 5, 200]
# Error moyenne:  0.08891013384321224
# Tuple testé: [20, 2, 5, 200]
# Error moyenne:  0.09847036328871893
# Tuple testé: [10, 3, 5, 200]
# Error moyenne:  0.11089866156787763
# Tuple testé: [20, 3, 5, 200]
# Error moyenne:  0.09273422562141492
# Tuple testé: [10, 2, 2, 400]
# Error moyenne:  0.0965583173996176
# Tuple testé: [20, 2, 2, 400]
# Error moyenne:  0.10038240917782026
# Tuple testé: [10, 3, 2, 400]
# Error moyenne:  0.09273422562141492
# Tuple testé: [20, 3, 2, 400]
# Error moyenne:  0.07552581261950286
# Tuple meilleur! On change pour:[20, 3, 2, 400] et une erreur moyenne de 0.07552581261950286
# Tuple testé: [10, 2, 5, 400]
# Error moyenne:  0.08604206500956023
# Tuple testé: [20, 2, 5, 400]
# Error moyenne:  0.09177820267686425
# Tuple testé: [10, 3, 5, 400]
# Error moyenne:  0.09082217973231357
# Tuple testé: [20, 3, 5, 400]
# Error moyenne:  0.0869980879541109
# Les hyperamètres sont:
# max_depth:20
# min_samples_leaf:3
# min_samples_split:2
# n_estimators:400

# %%
justesse_forest, confusion_matrix = forest.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# Justesse: 0.7387820512820513%
#    Prédit normal  Prédit malade
# 0       0.163462       0.211538
# 1       0.049679       0.575321

# %%
roc_forest, pres_rec_forest = forest.get_curves(x_test, y_test)

# %%
forest.reinit()
plot_learning_curve(forest.forest, "Forest",
                    x_train, y_train, train_sizes=np.linspace(0.1, 1.0, 5))

# %% [markdown]
# # Model Mixture

# %%
 mix = ModelMixture('None',hyperparams=[])

# %%
mix.train(x_train,y_train)
print("finish")
# Out:
# finish

# %%
justesse_mix, confusion_matrix = mix.get_confusion_matrix(x_test, y_test)
confusion_matrix = pd.DataFrame(confusion_matrix)
confusion_matrix.columns = ['Prédit normal', 'Prédit malade']
print(confusion_matrix.head())
# Out:
# Nombres de valeurs de test:234
# Nombres d'échantillons malades:390
# Nombres d'échantillons sains:624
# (624, 7)
# Justesse: 0.7243589743589743%
#    Prédit normal  Prédit malade
# 0       0.147436       0.227564
# 1       0.048077       0.576923

# %%
roc_mix, pres_rec_mix = mix.get_curves(x_test, y_test)

# %% [markdown]
# # Resultats

# %%
juste = pd.DataFrame([justesse_log,justesse_ada,justesse_mlp,justesse_linear,justesse_svmpoly,justesse_forest,justesse_svmrbf,justesse_mix]).T
juste.columns = ['log','ada','mlp','svm linear', 'svm poly', 'foret', 'svm rbf', 'mix']
juste.head()
# Out:
#         log       ada       mlp  svm linear  svm poly     foret   svm rbf  \
# 0  0.706731  0.719551  0.733974    0.714744  0.714744  0.738782  0.735577
#
#         mix
# 0  0.724359

# %% [markdown]
# On affiche pour finir l'ensemble des justesses des différents modèles et on voit que le multi layer perceptron a eu
